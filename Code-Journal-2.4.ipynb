# %%
#Connor Schwengel
#10/31/2025
import numpy as np
import matplotlib.pyplot as plt

# %%
random_numbers = np.random.poisson(lam=5, size=1000)

# %%
plt.hist(random_numbers, bins=100, edgecolor='black')

plt.xlabel("Value")
plt.ylabel("Frequency")
plt.title("Histogram of Poisson Distributed Random Numbers")

plt.grid(True)
plt.show()
